# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "AIzaSyDZWi5SF1_AhYz3MAr-uXqsvk_IrNcL7MI"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Hello how are you? ")
response.content
# Out:
# "I'm doing well, thank you for asking! As a large language model, I don't have feelings or personal experiences in the way humans do, but I'm functioning as intended and ready to assist you.\n\nHow are *you* doing today? Is there anything I can help you with?"

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"] = "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"
